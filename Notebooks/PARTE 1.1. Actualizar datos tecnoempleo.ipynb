# %%
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
from time import sleep
from datetime import datetime

# %%
# para comprobar que el codigo funciona correctamente
# usaremos el archivo mas actualizado, los resultados
# deberian ser vacíos
df = pd.read_csv('../csv/PARTE_1_1_Tecnoempleo_f.csv')

# %%
df
# Out:
#                                                    Urls  \
# 0     https://www.tecnoempleo.com/programador-fullst...
# 1     https://www.tecnoempleo.com/analista-programad...
# 2     https://www.tecnoempleo.com/senior-backend-dev...
# 3     https://www.tecnoempleo.com/software-engineeri...
# 4     https://www.tecnoempleo.com/front-developer-se...
# ...                                                 ...
# 3952  https://www.tecnoempleo.com/administrador-sist...
# 3953  https://www.tecnoempleo.com/desarrolladores-ja...
# 3954  https://www.tecnoempleo.com/arquitecto-fullsta...
# 3955  https://www.tecnoempleo.com/spark-engineer-mad...
# 3956  https://www.tecnoempleo.com/arquitecto-big-dat...
#
#                                         Oferta       Empresa  \
# 0                        Programador FullStack       Dev&del
# 1                  Analista Programador en PHP      Codicert
# 2     Senior Backend Developer (.NET/ Go/ PHP)       WebBeds
# 3                 Software Engineering Manager        Solera
# 4                       Front Developer Senior  Mytic Innova
# ...                                        ...           ...
# 3952              Administrador Sistemas Linux       Stratio
# 3953                      Desarrolladores Java       Stratio
# 3954                      Arquitecto Fullstack       Stratio
# 3955                            Spark Engineer       Stratio
# 3956                       Arquitecto Big Data       Stratio
#
#                    Funcion                                          Aptitudes  \
# 0     Analista Programador  ['java', 'javascript', 'spring', 'angular', 'r...
# 1              Programador  ['php7', 'phpunit', 'ajax', 'composer', 'poo',...
# 2              Programador  ['C#', 'Golang', 'PHP', 'git', 'kubernetes', '...
# 3     Analista Programador  ['Java', 'REST', 'API', 'Git', 'CI/CD', 'Hiber...
# 4     Analista Programador  ['Java', 'Angular', 'SQL', 'SCRUM', 'Git', 'Ht...
# ...                    ...                                                ...
# 3952         Administrador           ['linux', 'docker', 'ansible', 'python']
# 3953  Analista Programador      ['java', 'spring', 'boot', 'Spring', 'Cloud']
# 3954        Arquitecto TIC   ['jee', 'java', 'oracle', 'weblogic', 'eclipse']
# 3955        Arquitecto TIC  ['Spark', 'Hadoop', 'Cassandra', 'Mongo', 'DB'...
# 3956        Arquitecto TIC  ['Scala', 'Spark', 'Hadoop', 'MapReduce', 'NoS...
#
#                Requisito         Idiomas           Jornada  \
# 0     FP2/Grado Superior   Inglés (Alto)  Jornada completa
# 1     FP2/Grado Superior  Inglés (Medio)  Jornada completa
# 2           Sin estudios  Inglés (Medio)  Jornada completa
# 3     Ingeniero Superior   Inglés (Alto)  Jornada completa
# 4     Ingeniero Superior   Inglés (Alto)  Jornada completa
# ...                  ...             ...               ...
# 3952  FP2/Grado Superior             NaN  Intensiva Mañana
# 3953   Ingeniero Técnico             NaN  Jornada completa
# 3954  Ingeniero Superior             NaN  Jornada completa
# 3955   Ingeniero Técnico         Español  Jornada completa
# 3956   Ingeniero Técnico         Español  Jornada completa
#
#                                 Ubicacion Teletrabajo o Presencial  \
# 0                                  Madrid                  Híbrido
# 1                           Gzira - Malta               Presencial
# 2                        Palma - Baleares                  Híbrido
# 3            Alcobendas - Madrid - España                      NaN
# 4     Hospitalet de Llobregat - Barcelona                  Híbrido
# ...                                   ...                      ...
# 3952   Pozuelo De Alarcón - Madrid España                      NaN
# 3953                      Madrid - España                      NaN
# 3954                      Madrid - España                      NaN
# 3955            Pozuelo - Madrid - España                      NaN
# 3956            Pozuelo - Madrid - España                      NaN
#
#         Contrato      Salario    Experiencia  \
# 0     Indefinido          NaN         3 años
# 1       Temporal  30000 30000         2 años
# 2     Indefinido          NaN         3 años
# 3     Indefinido          NaN  Más de 5 años
# 4     Indefinido  27000 33000         2 años
# ...          ...          ...            ...
# 3952  Indefinido  33000 42000         3 años
# 3953  Indefinido          NaN         3 años
# 3954  Indefinido  30000 36000  Más de 5 años
# 3955  Indefinido          NaN         3 años
# 3956  Indefinido          NaN         3 años
#
#                                                   Texto Fecha_de_publicacion  \
# 0     Descripción de la oferta de empleo ¿Eres una p...           17/04/2025
# 1     Descripción de la oferta de empleo ¡Únete a nu...           17/04/2025
# 2     Descripción de la oferta de empleo How will yo...           17/04/2025
# 3     Descripción de la oferta de empleo 7+ years of...           17/04/2025
# 4     Descripción de la oferta de empleo Mytic Innov...           17/04/2025
# ...                                                 ...                  ...
# 3952  Descripción de la oferta de empleo En Stratio ...           16/05/2018
# 3953  Descripción de la oferta de empleo Desde Strat...           08/11/2017
# 3954  Descripción de la oferta de empleo Experiencia...           25/10/2017
# 3955  Descripción de la oferta de empleo Más de 3 añ...           03/10/2017
# 3956  Descripción de la oferta de empleo Arquitectur...           20/09/2017
#
#             Fecha_extraccion
# 0    2025-04-17 13:30:13.871
# 1    2025-04-17 13:30:15.038
# 2    2025-04-17 13:30:16.207
# 3    2025-04-17 13:30:17.374
# 4    2025-04-17 13:30:18.542
# ...                      ...
# 3952 2025-04-17 14:47:33.451
# 3953 2025-04-17 14:47:34.619
# 3954 2025-04-17 14:47:35.780
# 3955 2025-04-17 14:47:36.950
# 3956 2025-04-17 14:47:38.142
#
# [3957 rows x 16 columns]

# %%
#FUNCION PARA GENERAR LOS URLS NUEVOS
#ESTA FUNCION HA DE RECIBIR LA ENTRADA DE UN DF DE URLS
def nuevas_ofertas (df_urls):
    
    reps = int(BeautifulSoup(requests.get('https://www.tecnoempleo.com/ofertas-trabajo/?pagina=1').text, "html.parser").find("h1").text.split()[0].replace(".",""))
    links = [f"https://www.tecnoempleo.com/ofertas-trabajo/?pagina={i+1}" for i in range(reps//30+1)]
    
    nuevo = []
    urls = []
    oferta = []
    empresa = []
    
    for i in links:
        response = requests.get(i)
        soup = BeautifulSoup(response.text, "html.parser")
        for j in soup.find_all("div", class_ = "row fs--15"):
            url = j.find("a")["href"]
            if url not in df_urls.values:
                nuevo.append(url)
                try:
                    oferta.append(j.find("h3").find("a")["title"])
                except:
                    oferta.append(np.nan)
                try:
                    empresa.append(j.find("a", class_ = "text-primary link-muted").text)
                except:
                    empresa.append(np.nan)
                
            
    return pd.DataFrame({"Urls": nuevo, "Oferta": oferta, "Empresa": empresa})
    
df_nuevo = nuevas_ofertas(df["Urls"])

# %%
df_nuevo
# Out:
#                                                   Urls  \
# 0    https://www.tecnoempleo.com/machine-learning-e...
# 1    https://www.tecnoempleo.com/programadores-cons...
# 2    https://www.tecnoempleo.com/senior-backend-dev...
# 3    https://www.tecnoempleo.com/administrador-sist...
# 4    https://www.tecnoempleo.com/backend-developer-...
# ..                                                 ...
# 877  https://www.tecnoempleo.com/operational-perfor...
# 878  https://www.tecnoempleo.com/director-operacion...
# 879  https://www.tecnoempleo.com/desarrollador-pyth...
# 880  https://www.tecnoempleo.com/qa-tester-manager-...
# 881  https://www.tecnoempleo.com/ingeniero-simulaci...
#
#                                   Oferta                      Empresa
# 0              Machine Learning Engineer                    Dataforce
# 1      Programadores/as y Consultores/as           Deister Consulting
# 2               Senior Backend Developer           THE MILL ADVENTURE
# 3    Administrador de Sistemas Jr (DATA)                     PUE DATA
# 4                      Backend Developer                       Coosto
# ..                                   ...                          ...
# 877      Operational performance analyst                 Michael Page
# 878            Director/a de Operaciones                 Michael Page
# 879    Desarrollador/a Python para Cloud                          GMV
# 880     QA TESTER Manager (Ingles B2/C1)  Krell Consulting & Training
# 881      Ingeniero/a de simulación C/C++                          GMV
#
# [882 rows x 3 columns]

# %%
def extracción_nurls (df_urls):
    
    fecha_de_publicacion = []
    fecha_extraccion = []
    aptitudes = []
    texto = []
    funcion = []
    requisito = []
    salario = []
    contrato = []
    jornada = []
    idiomas = []
    ubicacion = []
    experiencia = []
    
    for i in df_urls:
        
        response = requests.get(i)
        soup = BeautifulSoup(response.text, "html.parser")
        numeros = []
        formacion = False
        contra = False
        jorn = False
        idiom = False
        puesto = False
        ubi = False
        text = False
        exp = False
        # EXTRACCION DE DATOS
        # Fecha de oferta
        try:
            fecha_de_publicacion.append(soup.find("span", class_ = "ml-4").text.strip()[:10])
        except:
            fecha_de_publicacion.append(np.nan)

        # Momento de extracción
        fecha_extraccion.append(datetime.now())
    
        # Aptitudes
        try:
            aptitudes.append(soup.find("div", class_= "pl--12 pr--12").text.split())
        except:
            aptitudes.append(np.nan)
            
        # Descripción de la oferta
        for k in soup.find_all("div", class_ = "mt-4"):
            if k.find("p", class_ = "fs--16 text-gray-800"):
                texto.append(" ".join(k.text.split()).strip())
                text = True
                break
        if not text:
            texto.append(np.nan)
    
        # Funcion o puesto de trabajo
        for k in soup.find_all("li", class_ = "list-item clearfix border-bottom py-2"):
            if k.find("i", class_ = "fi fi-users"):
                funcion.append(" ".join([" ".join(i.replace("Funciones", "").split()) for i in (k.text.split())]).strip())
                puesto = True
                break
        if not puesto:
            funcion.append(np.nan)
            
        # Requisitos min
        for k in soup.find_all("div", class_ = "d-flex py-2"):
            if k.find("i", class_ = "fi fi-graduate"):
                requisito.append((k.text.split(":")[1]).strip())
                formacion = True
                break
        if not formacion:
            requisito.append(np.nan)
    
        # Salario min max
        for l in soup.find_all("li", class_ = "list-item clearfix border-bottom py-2"):
            if l.find("i", class_="fi fi-plus"):
                for k in l.text.strip().replace(".","")[:-1].split():
                    if k.isdigit():
                        numeros.append(k)
        salario.append(" ".join(numeros) if numeros else np.nan)
    
        # Tipo de contrato
        for l in soup.find_all("li", class_ = "list-item clearfix border-bottom py-2"):
            if l.find("i", class_ = "fi fi-task-list"):
                contrato.append(" ".join([" ".join(i.replace("Tipo", "").replace("contrato", "").split()) for i in (l.text.split())]).strip())
                contra = True
                break
        if not contra:
            contrato.append(np.nan)
    
        # Jornada (completa, media,etc)
        for l in soup.find_all("li", class_ = "list-item clearfix border-bottom py-2"):
            if l.find("i", class_ = "fi fi-calendar"):
                jornada.append(" ".join(l.text.split()[:2]).strip())
                jorn = True
                break
        if not jorn:
            jornada.append(np.nan)
            
        # Idiomas requeridos
        for l in soup.find_all("div", class_ = "d-flex py-2"):
            if l.find("i", class_ = "fi fi-globe"):
                idiomas.append(" ".join((l.text.replace("|", "").split(":")[1]).split()))
                idiom = True
                break
        if not idiom:
            idiomas.append(np.nan)
    
        # Ubi job
        for k in soup.find_all("li", class_ = "list-item clearfix border-bottom py-2"):
            if k.find("i", class_ = "fi fi-pin"):
                ubicacion.append(" ".join(k.text.split()).strip())
                ubi = True
                break
        if not ubi:
            ubicacion.append(np.nan)
            
        # Experiencia (años)
        for k in soup.find_all("li", class_ = "list-item clearfix border-bottom py-2"):
            if k.find("i", class_ = "fi fi-shield-ok"):
                experiencia.append(" ".join(k.text.split()).replace("Experiencia", "").strip())
                exp = True
                break
        if not exp:
            experiencia.append(np.nan)
        
    sleep(1)

    return pd.DataFrame({"Funcion": funcion,"Aptitudes": aptitudes,
                         "Requisito": requisito,"Jornada": jornada,
                         "Contrato": contrato,"Salario": salario,
                         "Fecha_de_publicacion": fecha_de_publicacion,"Ubicacion": ubicacion,
                         "Idiomas": idiomas,"Texto": texto,
                         "Experiencia": experiencia,"Fecha_extraccion": fecha_extraccion})

df_nuevo1 = extracción_nurls (df_nuevo["Urls"])
df_nuevo1
# Out:
#                                       Funcion  \
# 0    Inteligencia Artificial/Machine Learning
# 1                                   Consultor
# 2                                 Programador
# 3                           Base de Datos/DBA
# 4                                      DevOps
# ..                                        ...
# 877                      Ingenieros/Industria
# 878                      Ingenieros/Industria
# 879                               Programador
# 880                                    Tester
# 881                               Programador
#
#                                              Aptitudes  \
# 0                    [Python, ML, PyTorch, TensorFlow]
# 1    [java, sql, javascript, scala, excel, cad, off...
# 2                [NodeJS, Typescript, AWS, JavaScript]
# 3              [Linux, Databricks, AWS, Scala, Python]
# 4    [Kafka, RabbitMQ, MongoDB, Grafana, SOLID, Go,...
# ..                                                 ...
# 877                                       [Ingenieria]
# 878                                      [Lean, Sigma]
# 879   [Python, Lambdas, Boto3, Terraform, Terraground]
# 880                                       [qa, tester]
# 881  [C, C++, Linux, Git, Eclipse, Visual, Studio, ...
#
#                    Requisito           Jornada            Contrato  \
# 0    Postgrado EEES (Máster)  Jornada completa          Indefinido
# 1         FP2/Grado Superior  Jornada completa          Indefinido
# 2                 Licenciado  Jornada completa  Freelance/Autónomo
# 3                  Diplomado  Jornada completa          Indefinido
# 4                 Licenciado  Jornada completa          Indefinido
# ..                       ...               ...                 ...
# 877                      NaN  Jornada completa          Indefinido
# 878                      NaN  Jornada completa          Indefinido
# 879                      NaN  Jornada completa          Indefinido
# 880                      NaN  Jornada completa          Indefinido
# 881                      NaN  Jornada completa          Indefinido
#
#          Salario Fecha_de_publicacion               Ubicacion        Idiomas  \
# 0            NaN           09/05/2025  Barcelona (Presencial)  Inglés (Alto)
# 1            NaN           09/05/2025         Madrid - España            NaN
# 2            NaN           09/05/2025          100% En remoto  Inglés (Alto)
# 3    18000 21000           09/05/2025        Madrid (Híbrido)            NaN
# 4    36000 42000           09/05/2025       Alicante - España  Inglés (Alto)
# ..           ...                  ...                     ...            ...
# 877          NaN           21/04/2025         Madrid - España            NaN
# 878          NaN           21/04/2025      Barcelona - España            NaN
# 879          NaN           15/04/2025        Madrid (Híbrido)            NaN
# 880          NaN           28/03/2025        Madrid (Híbrido)  Inglés (Alto)
# 881          NaN           21/03/2025        Madrid (Híbrido)            NaN
#
#                                                  Texto      Experiencia  \
# 0    Descripción de la oferta de empleo Work Locati...           2 años
# 1    Descripción de la oferta de empleo OFERTA LABO...  Menos de un año
# 2    Descripción de la oferta de empleo The Mill Ad...         3-5 años
# 3    Descripción de la oferta de empleo ¡Impulsa tu...              Sin
# 4    Descripción de la oferta de empleo Backend Sof...         3-5 años
# ..                                                 ...              ...
# 877  Descripción de la oferta de empleo Perfil busc...         3-5 años
# 878  Descripción de la oferta de empleo Perfil busc...           3 años
# 879  Descripción de la oferta de empleo Si crees qu...           3 años
# 880  Descripción de la oferta de empleo Descripción...         3-5 años
# 881  Descripción de la oferta de empleo Si siempre ...           3 años
#
#               Fecha_extraccion
# 0   2025-05-11 19:15:38.983522
# 1   2025-05-11 19:15:39.152945
# 2   2025-05-11 19:15:39.335612
# 3   2025-05-11 19:15:39.500799
# 4   2025-05-11 19:15:39.663318
# ..                         ...
# 877 2025-05-11 19:18:10.333900
# 878 2025-05-11 19:18:10.491720
# 879 2025-05-11 19:18:10.676720
# 880 2025-05-11 19:18:10.842889
# 881 2025-05-11 19:18:11.048937
#
# [882 rows x 12 columns]

# %%
df_final = pd.concat([df_nuevo, df_nuevo1], axis = 1)
df_final
# Out:
#                                                   Urls  \
# 0    https://www.tecnoempleo.com/machine-learning-e...
# 1    https://www.tecnoempleo.com/programadores-cons...
# 2    https://www.tecnoempleo.com/senior-backend-dev...
# 3    https://www.tecnoempleo.com/administrador-sist...
# 4    https://www.tecnoempleo.com/backend-developer-...
# ..                                                 ...
# 877  https://www.tecnoempleo.com/operational-perfor...
# 878  https://www.tecnoempleo.com/director-operacion...
# 879  https://www.tecnoempleo.com/desarrollador-pyth...
# 880  https://www.tecnoempleo.com/qa-tester-manager-...
# 881  https://www.tecnoempleo.com/ingeniero-simulaci...
#
#                                   Oferta                      Empresa  \
# 0              Machine Learning Engineer                    Dataforce
# 1      Programadores/as y Consultores/as           Deister Consulting
# 2               Senior Backend Developer           THE MILL ADVENTURE
# 3    Administrador de Sistemas Jr (DATA)                     PUE DATA
# 4                      Backend Developer                       Coosto
# ..                                   ...                          ...
# 877      Operational performance analyst                 Michael Page
# 878            Director/a de Operaciones                 Michael Page
# 879    Desarrollador/a Python para Cloud                          GMV
# 880     QA TESTER Manager (Ingles B2/C1)  Krell Consulting & Training
# 881      Ingeniero/a de simulación C/C++                          GMV
#
#                                       Funcion  \
# 0    Inteligencia Artificial/Machine Learning
# 1                                   Consultor
# 2                                 Programador
# 3                           Base de Datos/DBA
# 4                                      DevOps
# ..                                        ...
# 877                      Ingenieros/Industria
# 878                      Ingenieros/Industria
# 879                               Programador
# 880                                    Tester
# 881                               Programador
#
#                                              Aptitudes  \
# 0                    [Python, ML, PyTorch, TensorFlow]
# 1    [java, sql, javascript, scala, excel, cad, off...
# 2                [NodeJS, Typescript, AWS, JavaScript]
# 3              [Linux, Databricks, AWS, Scala, Python]
# 4    [Kafka, RabbitMQ, MongoDB, Grafana, SOLID, Go,...
# ..                                                 ...
# 877                                       [Ingenieria]
# 878                                      [Lean, Sigma]
# 879   [Python, Lambdas, Boto3, Terraform, Terraground]
# 880                                       [qa, tester]
# 881  [C, C++, Linux, Git, Eclipse, Visual, Studio, ...
#
#                    Requisito           Jornada            Contrato  \
# 0    Postgrado EEES (Máster)  Jornada completa          Indefinido
# 1         FP2/Grado Superior  Jornada completa          Indefinido
# 2                 Licenciado  Jornada completa  Freelance/Autónomo
# 3                  Diplomado  Jornada completa          Indefinido
# 4                 Licenciado  Jornada completa          Indefinido
# ..                       ...               ...                 ...
# 877                      NaN  Jornada completa          Indefinido
# 878                      NaN  Jornada completa          Indefinido
# 879                      NaN  Jornada completa          Indefinido
# 880                      NaN  Jornada completa          Indefinido
# 881                      NaN  Jornada completa          Indefinido
#
#          Salario Fecha_de_publicacion               Ubicacion        Idiomas  \
# 0            NaN           09/05/2025  Barcelona (Presencial)  Inglés (Alto)
# 1            NaN           09/05/2025         Madrid - España            NaN
# 2            NaN           09/05/2025          100% En remoto  Inglés (Alto)
# 3    18000 21000           09/05/2025        Madrid (Híbrido)            NaN
# 4    36000 42000           09/05/2025       Alicante - España  Inglés (Alto)
# ..           ...                  ...                     ...            ...
# 877          NaN           21/04/2025         Madrid - España            NaN
# 878          NaN           21/04/2025      Barcelona - España            NaN
# 879          NaN           15/04/2025        Madrid (Híbrido)            NaN
# 880          NaN           28/03/2025        Madrid (Híbrido)  Inglés (Alto)
# 881          NaN           21/03/2025        Madrid (Híbrido)            NaN
#
#                                                  Texto      Experiencia  \
# 0    Descripción de la oferta de empleo Work Locati...           2 años
# 1    Descripción de la oferta de empleo OFERTA LABO...  Menos de un año
# 2    Descripción de la oferta de empleo The Mill Ad...         3-5 años
# 3    Descripción de la oferta de empleo ¡Impulsa tu...              Sin
# 4    Descripción de la oferta de empleo Backend Sof...         3-5 años
# ..                                                 ...              ...
# 877  Descripción de la oferta de empleo Perfil busc...         3-5 años
# 878  Descripción de la oferta de empleo Perfil busc...           3 años
# 879  Descripción de la oferta de empleo Si crees qu...           3 años
# 880  Descripción de la oferta de empleo Descripción...         3-5 años
# 881  Descripción de la oferta de empleo Si siempre ...           3 años
#
#               Fecha_extraccion
# 0   2025-05-11 19:15:38.983522
# 1   2025-05-11 19:15:39.152945
# 2   2025-05-11 19:15:39.335612
# 3   2025-05-11 19:15:39.500799
# 4   2025-05-11 19:15:39.663318
# ..                         ...
# 877 2025-05-11 19:18:10.333900
# 878 2025-05-11 19:18:10.491720
# 879 2025-05-11 19:18:10.676720
# 880 2025-05-11 19:18:10.842889
# 881 2025-05-11 19:18:11.048937
#
# [882 rows x 15 columns]

# %%
## De esta manera crearemos la columna de Teletrabajo o Presencial con la de Ubicacion.
def ext_teletrabajo(df_ubicacion):
    teletrabajo = []
    for i in df_ubicacion.values:
        if not pd.isna(i):
            if "Presencial" in i:
                teletrabajo.append("Presencial")
                
            elif "remoto" in i:
                teletrabajo.append("100% remoto")
                
            elif "(Híbrido)" in i:
                teletrabajo.append("Híbrido")
                
            else:
                teletrabajo.append(np.nan)
        else:
            teletrabajo.append(i)
        
    return teletrabajo

df_final["Teletrabajo o Presencial"] = ext_teletrabajo(df_final["Ubicacion"])
df_final
# Out:
#                                                   Urls  \
# 0    https://www.tecnoempleo.com/machine-learning-e...
# 1    https://www.tecnoempleo.com/programadores-cons...
# 2    https://www.tecnoempleo.com/senior-backend-dev...
# 3    https://www.tecnoempleo.com/administrador-sist...
# 4    https://www.tecnoempleo.com/backend-developer-...
# ..                                                 ...
# 877  https://www.tecnoempleo.com/operational-perfor...
# 878  https://www.tecnoempleo.com/director-operacion...
# 879  https://www.tecnoempleo.com/desarrollador-pyth...
# 880  https://www.tecnoempleo.com/qa-tester-manager-...
# 881  https://www.tecnoempleo.com/ingeniero-simulaci...
#
#                                   Oferta                      Empresa  \
# 0              Machine Learning Engineer                    Dataforce
# 1      Programadores/as y Consultores/as           Deister Consulting
# 2               Senior Backend Developer           THE MILL ADVENTURE
# 3    Administrador de Sistemas Jr (DATA)                     PUE DATA
# 4                      Backend Developer                       Coosto
# ..                                   ...                          ...
# 877      Operational performance analyst                 Michael Page
# 878            Director/a de Operaciones                 Michael Page
# 879    Desarrollador/a Python para Cloud                          GMV
# 880     QA TESTER Manager (Ingles B2/C1)  Krell Consulting & Training
# 881      Ingeniero/a de simulación C/C++                          GMV
#
#                                       Funcion  \
# 0    Inteligencia Artificial/Machine Learning
# 1                                   Consultor
# 2                                 Programador
# 3                           Base de Datos/DBA
# 4                                      DevOps
# ..                                        ...
# 877                      Ingenieros/Industria
# 878                      Ingenieros/Industria
# 879                               Programador
# 880                                    Tester
# 881                               Programador
#
#                                              Aptitudes  \
# 0                    [Python, ML, PyTorch, TensorFlow]
# 1    [java, sql, javascript, scala, excel, cad, off...
# 2                [NodeJS, Typescript, AWS, JavaScript]
# 3              [Linux, Databricks, AWS, Scala, Python]
# 4    [Kafka, RabbitMQ, MongoDB, Grafana, SOLID, Go,...
# ..                                                 ...
# 877                                       [Ingenieria]
# 878                                      [Lean, Sigma]
# 879   [Python, Lambdas, Boto3, Terraform, Terraground]
# 880                                       [qa, tester]
# 881  [C, C++, Linux, Git, Eclipse, Visual, Studio, ...
#
#                    Requisito           Jornada            Contrato  \
# 0    Postgrado EEES (Máster)  Jornada completa          Indefinido
# 1         FP2/Grado Superior  Jornada completa          Indefinido
# 2                 Licenciado  Jornada completa  Freelance/Autónomo
# 3                  Diplomado  Jornada completa          Indefinido
# 4                 Licenciado  Jornada completa          Indefinido
# ..                       ...               ...                 ...
# 877                      NaN  Jornada completa          Indefinido
# 878                      NaN  Jornada completa          Indefinido
# 879                      NaN  Jornada completa          Indefinido
# 880                      NaN  Jornada completa          Indefinido
# 881                      NaN  Jornada completa          Indefinido
#
#          Salario Fecha_de_publicacion               Ubicacion        Idiomas  \
# 0            NaN           09/05/2025  Barcelona (Presencial)  Inglés (Alto)
# 1            NaN           09/05/2025         Madrid - España            NaN
# 2            NaN           09/05/2025          100% En remoto  Inglés (Alto)
# 3    18000 21000           09/05/2025        Madrid (Híbrido)            NaN
# 4    36000 42000           09/05/2025       Alicante - España  Inglés (Alto)
# ..           ...                  ...                     ...            ...
# 877          NaN           21/04/2025         Madrid - España            NaN
# 878          NaN           21/04/2025      Barcelona - España            NaN
# 879          NaN           15/04/2025        Madrid (Híbrido)            NaN
# 880          NaN           28/03/2025        Madrid (Híbrido)  Inglés (Alto)
# 881          NaN           21/03/2025        Madrid (Híbrido)            NaN
#
#                                                  Texto      Experiencia  \
# 0    Descripción de la oferta de empleo Work Locati...           2 años
# 1    Descripción de la oferta de empleo OFERTA LABO...  Menos de un año
# 2    Descripción de la oferta de empleo The Mill Ad...         3-5 años
# 3    Descripción de la oferta de empleo ¡Impulsa tu...              Sin
# 4    Descripción de la oferta de empleo Backend Sof...         3-5 años
# ..                                                 ...              ...
# 877  Descripción de la oferta de empleo Perfil busc...         3-5 años
# 878  Descripción de la oferta de empleo Perfil busc...           3 años
# 879  Descripción de la oferta de empleo Si crees qu...           3 años
# 880  Descripción de la oferta de empleo Descripción...         3-5 años
# 881  Descripción de la oferta de empleo Si siempre ...           3 años
#
#               Fecha_extraccion Teletrabajo o Presencial
# 0   2025-05-11 19:15:38.983522               Presencial
# 1   2025-05-11 19:15:39.152945                      NaN
# 2   2025-05-11 19:15:39.335612              100% remoto
# 3   2025-05-11 19:15:39.500799                  Híbrido
# 4   2025-05-11 19:15:39.663318                      NaN
# ..                         ...                      ...
# 877 2025-05-11 19:18:10.333900                      NaN
# 878 2025-05-11 19:18:10.491720                      NaN
# 879 2025-05-11 19:18:10.676720                  Híbrido
# 880 2025-05-11 19:18:10.842889                  Híbrido
# 881 2025-05-11 19:18:11.048937                  Híbrido
#
# [882 rows x 16 columns]

# %%
df_final = df_final[df.columns]
df_final
# Out:
#                                                   Urls  \
# 0    https://www.tecnoempleo.com/machine-learning-e...
# 1    https://www.tecnoempleo.com/programadores-cons...
# 2    https://www.tecnoempleo.com/senior-backend-dev...
# 3    https://www.tecnoempleo.com/administrador-sist...
# 4    https://www.tecnoempleo.com/backend-developer-...
# ..                                                 ...
# 877  https://www.tecnoempleo.com/operational-perfor...
# 878  https://www.tecnoempleo.com/director-operacion...
# 879  https://www.tecnoempleo.com/desarrollador-pyth...
# 880  https://www.tecnoempleo.com/qa-tester-manager-...
# 881  https://www.tecnoempleo.com/ingeniero-simulaci...
#
#                                   Oferta                      Empresa  \
# 0              Machine Learning Engineer                    Dataforce
# 1      Programadores/as y Consultores/as           Deister Consulting
# 2               Senior Backend Developer           THE MILL ADVENTURE
# 3    Administrador de Sistemas Jr (DATA)                     PUE DATA
# 4                      Backend Developer                       Coosto
# ..                                   ...                          ...
# 877      Operational performance analyst                 Michael Page
# 878            Director/a de Operaciones                 Michael Page
# 879    Desarrollador/a Python para Cloud                          GMV
# 880     QA TESTER Manager (Ingles B2/C1)  Krell Consulting & Training
# 881      Ingeniero/a de simulación C/C++                          GMV
#
#                                       Funcion  \
# 0    Inteligencia Artificial/Machine Learning
# 1                                   Consultor
# 2                                 Programador
# 3                           Base de Datos/DBA
# 4                                      DevOps
# ..                                        ...
# 877                      Ingenieros/Industria
# 878                      Ingenieros/Industria
# 879                               Programador
# 880                                    Tester
# 881                               Programador
#
#                                              Aptitudes  \
# 0                    [Python, ML, PyTorch, TensorFlow]
# 1    [java, sql, javascript, scala, excel, cad, off...
# 2                [NodeJS, Typescript, AWS, JavaScript]
# 3              [Linux, Databricks, AWS, Scala, Python]
# 4    [Kafka, RabbitMQ, MongoDB, Grafana, SOLID, Go,...
# ..                                                 ...
# 877                                       [Ingenieria]
# 878                                      [Lean, Sigma]
# 879   [Python, Lambdas, Boto3, Terraform, Terraground]
# 880                                       [qa, tester]
# 881  [C, C++, Linux, Git, Eclipse, Visual, Studio, ...
#
#                    Requisito        Idiomas           Jornada  \
# 0    Postgrado EEES (Máster)  Inglés (Alto)  Jornada completa
# 1         FP2/Grado Superior            NaN  Jornada completa
# 2                 Licenciado  Inglés (Alto)  Jornada completa
# 3                  Diplomado            NaN  Jornada completa
# 4                 Licenciado  Inglés (Alto)  Jornada completa
# ..                       ...            ...               ...
# 877                      NaN            NaN  Jornada completa
# 878                      NaN            NaN  Jornada completa
# 879                      NaN            NaN  Jornada completa
# 880                      NaN  Inglés (Alto)  Jornada completa
# 881                      NaN            NaN  Jornada completa
#
#                   Ubicacion Teletrabajo o Presencial            Contrato  \
# 0    Barcelona (Presencial)               Presencial          Indefinido
# 1           Madrid - España                      NaN          Indefinido
# 2            100% En remoto              100% remoto  Freelance/Autónomo
# 3          Madrid (Híbrido)                  Híbrido          Indefinido
# 4         Alicante - España                      NaN          Indefinido
# ..                      ...                      ...                 ...
# 877         Madrid - España                      NaN          Indefinido
# 878      Barcelona - España                      NaN          Indefinido
# 879        Madrid (Híbrido)                  Híbrido          Indefinido
# 880        Madrid (Híbrido)                  Híbrido          Indefinido
# 881        Madrid (Híbrido)                  Híbrido          Indefinido
#
#          Salario      Experiencia  \
# 0            NaN           2 años
# 1            NaN  Menos de un año
# 2            NaN         3-5 años
# 3    18000 21000              Sin
# 4    36000 42000         3-5 años
# ..           ...              ...
# 877          NaN         3-5 años
# 878          NaN           3 años
# 879          NaN           3 años
# 880          NaN         3-5 años
# 881          NaN           3 años
#
#                                                  Texto Fecha_de_publicacion  \
# 0    Descripción de la oferta de empleo Work Locati...           09/05/2025
# 1    Descripción de la oferta de empleo OFERTA LABO...           09/05/2025
# 2    Descripción de la oferta de empleo The Mill Ad...           09/05/2025
# 3    Descripción de la oferta de empleo ¡Impulsa tu...           09/05/2025
# 4    Descripción de la oferta de empleo Backend Sof...           09/05/2025
# ..                                                 ...                  ...
# 877  Descripción de la oferta de empleo Perfil busc...           21/04/2025
# 878  Descripción de la oferta de empleo Perfil busc...           21/04/2025
# 879  Descripción de la oferta de empleo Si crees qu...           15/04/2025
# 880  Descripción de la oferta de empleo Descripción...           28/03/2025
# 881  Descripción de la oferta de empleo Si siempre ...           21/03/2025
#
#               Fecha_extraccion
# 0   2025-05-11 19:15:38.983522
# 1   2025-05-11 19:15:39.152945
# 2   2025-05-11 19:15:39.335612
# 3   2025-05-11 19:15:39.500799
# 4   2025-05-11 19:15:39.663318
# ..                         ...
# 877 2025-05-11 19:18:10.333900
# 878 2025-05-11 19:18:10.491720
# 879 2025-05-11 19:18:10.676720
# 880 2025-05-11 19:18:10.842889
# 881 2025-05-11 19:18:11.048937
#
# [882 rows x 16 columns]

# %%
df_final.to_csv('../csv/PARTE_1_1_act_tecno.csv', index=False)

# %%
df_f = pd.concat([df, df_final], ignore_index = True)
df_f.to_csv('../csv/PARTE_1_1_Tecnoempleo_f.csv', index=False)

# %%
# funciona como se esperaba
