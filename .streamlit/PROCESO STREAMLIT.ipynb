# %%
REQUERIMIENTOS

0. Definir la paginación y las secciones principales: 
Las vista principal (landing page) y  La vista de presentación de datos (filtros, mapa, dashboard, etc.)  
1. Como usuario, quiero visualizar un mapa interactivo con las ofertas de empleo distribuidas geográficamente para conocer las oportunidades por zona. 
2. Como usuario, quiero poder filtrar las ofertas por ubicación, salario, tipo de contrato, tecnologías requeridas y experiencia para encontrar las más adecuadas. 
3. Como usuario, quiero ver una tabla con información detallada de las ofertas de empleo para comparar sus características principales. 
4. Como usuario, quiero visualizar gráficos interactivos sobre tendencias salariales, tecnologías más demandadas y empresas que más contratan. 
5. Como usuario, quiero acceder a una ficha detallada de cada oferta que incluya la descripción del puesto, requisitos y beneficios. 
6. Como usuario, quiero comparar múltiples ofertas de empleo para evaluar cuál se adapta mejor a mi perfil. 
7. Como cliente, quiero acceder a un dashboard en PowerBI con métricas clave sobre el mercado laboral tecnológico para tomar decisiones estratégicas.
8. Como cliente, quiero visualizar tendencias de demanda de tecnologías y skills a lo largo del tiempo para ajustar mis procesos de contratación.
9. Como cliente, quiero ver un esquema visual de la base de datos para comprender mejor la estructura y fuentes de los datos almacenados.
10. Como cliente, quiero filtrar datos por empresa, sector y ubicación para analizar la competencia y mejorar mis estrategias de captación de talento. 
11. Como usuario o cliente, quiero utilizar filtros avanzados para encontrar ofertas de empleo o tendencias de manera eficiente. 
12. Como usuario o cliente, quiero realizar búsquedas rápidas dentro de la tabla de datos para acceder a información específica sin perder tiempo. 
13. Como usuario o cliente, quiero que la plataforma implemente paginación para navegar por grandes volúmenes de datos sin problemas. 
14. Como usuario o cliente, quiero que la información de los dashboards esté siempre actualizada con las ofertas y tendencias más recientes del mercado. 
15. Como usuario o cliente, quiero que la aplicación sea intuitiva y fácil de navegar para aprovechar al máximo sus funcionalidades. 


VISUALIZACION
¿Cómo tiene que ser el visor?
En estética :
    Tema de colores: azul oscuro y gris claro.
    Tipografía sans-serif moderna.
    Barra lateral fija con íconos para navegar páginas.
    Uso de tarjetas (st.card) para las ofertas destacadas.
    Diseño responsive que se adapte a móvil.
Funcionalidad 
Quiero elementos interactivos (mapa, gráficos, tablas, buscador, paginación, comparador).



PROBLEMAS Y ALTERNATIVAS

PROGRAMA USADO
Visual studio 
Spyder + ananconda prompt de un solo uso

CODIGO 
Erorr al cargar de CSV definitvo. 
Varios notebooks con diferentes apartados, para encontrar errores. 
        - En su propio notebook, estructura de las carpetas y .py por cada uno. 
        - Al ejecutar APP da error, contados 15 veces error... Lo dejo aparcado y sigo. 
   
    


PRIMERA IDEA DE VISUALIZACION 

Carga de Datos: Lectura del archivo CSV y procesamiento inicial.

Filtros Interactivos: Permitir a los usuarios filtrar ofertas por ubicación, salario, tipo de contrato, tecnologías requeridas, experiencia, etc.

Visualización de Datos:

    Mapa Interactivo: Mostrar las ofertas geográficamente.

    Gráficos: Tendencias salariales, tecnologías más demandadas, empresas que más contratan.

    Tabla Detallada: Información detallada de las ofertas para comparación.

Ficha Detallada de la Oferta: Al seleccionar una oferta, mostrar descripción, requisitos y beneficios.

Comparación de Ofertas: Permitir comparar múltiples ofertas seleccionadas.

Dashboard para Clientes: Métricas clave sobre el mercado laboral tecnológico.

Actualización de Datos: Asegurar que la información esté siempre actualizada.





Próximos Pasos

    Integrar Mapas: Utilizar bibliotecas como folium o pydeck para mostrar las ofertas en un mapa interactivo.

    Dashboard para Clientes: Crear un panel con métricas clave utilizando st.metric y gráficos adicionales.

    Comparación de Ofertas: Implementar una funcionalidad que permita seleccionar múltiples ofertas y compararlas lado a lado.

    Actualización Automática: Configurar la aplicación para que actualice los datos automáticamente a intervalos regulares.
